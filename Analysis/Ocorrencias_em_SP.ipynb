# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasmontanheiro/colab/blob/main/Analysis/Ocorrencias_em_SP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ocorrências em São Paulo
#
# Dados exploratórios da Secretaria de Segurança Pública do Estado de São Paulo.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/lucasmontanheiro/db/main/csv/ocorrencias_em_sp.csv")

# %%
data.describe()
data.head
# Out:
# <bound method NDFrame.head of      periodo   item                                  tipo_ocorrencia  \
# 0       20094   NaN  Ocorrências policiais registradas, por natureza
# 1       20094   NaN  Ocorrências policiais registradas, por natureza
# 2       20094   NaN  Ocorrências policiais registradas, por natureza
# 3       20094   NaN  Ocorrências policiais registradas, por natureza
# 4       20094   NaN  Ocorrências policiais registradas, por natureza
# ..        ...   ...                                              ...
# 401     20112   NaN      Ocorrências policiais registradas, por tipo
# 402     20112   NaN      Ocorrências policiais registradas, por tipo
# 403     20112   NaN      Ocorrências policiais registradas, por tipo
# 404     20112   NaN      Ocorrências policiais registradas, por tipo
# 405     20112   NaN      Ocorrências policiais registradas, por tipo
#
#               ocorrencia  obs  \
# 0        Contra a pessoa  NaN
# 1    Contra o patrimonio  NaN
# ...

# %%
data.dtypes
# Out:
# periodo              int64
# item               float64
# tipo_ocorrencia     object
# ocorrencia          object
# obs                float64
# fonte               object
# link               float64
# data_capital         int64
# data_grandesp        int64
# data_interior        int64
# data_deinter1      float64
# data_deinter2      float64
# data_deinter3      float64
# data_deinter4      float64
# data_deinter5      float64
# data_deinter6      float64
# data_deinter7      float64
# data_deinter8      float64
# data_deinter9      float64
# data_estado          int64
# dtype: object

# %%
columns = ["ocorrencia", "data_estado", "periodo "]
data = data[columns]

# %%
# Pandas profiling report
#profile = ProfileReport(data, title='SSP Data', explorative=True)

# %%
# export analysis results to an html page, for sharing to a wider audience and non-Jupyter users.
#profile.to_file('SSP Data.html')

# %%
g = sns.FacetGrid(data, row="ocorrencia")
g.map(sns.histplot, "periodo ", "data_estado")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
