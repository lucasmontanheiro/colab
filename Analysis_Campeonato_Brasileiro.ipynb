# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasmontanheiro/colab/blob/main/Analysis_Campeonato_Brasileiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/lucasmontanheiro/db/main/csv/campeonato_brasileiro_final_position.csv")

# %%
#data.head()
data.set_index("ano")
#pd.to_numeric(data)
data.dtypes
# Out:
# ano                       int64
# america_mineiro         float64
# athletico_paranaense      int64
# atletico_goianiense     float64
# atletico_mineiro          int64
# avai                    float64
# botafogo                float64
# ceara                   float64
# corinthians               int64
# coritiba                float64
# cuiaba                  float64
# fortaleza               float64
# flamengo                  int64
# fluminense                int64
# goias                   float64
# internacional           float64
# juventude               float64
# palmeiras                 int64
# red_bull_bragantino     float64
# santos                    int64
# sao_paulo                 int64
# gremio                  float64
# bahia                   float64
# sport                   float64
# vasco_da_gama           float64
# cruzeiro                float64
# csa                     float64
# chapecoense             float64
# vitoria                 float64
# ...

# %%
#sns.lineplot(data=data, x="year", y="passengers")
sns.lineplot(data=data)
